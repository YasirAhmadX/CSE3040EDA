# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jobs-dataset-from-glassdoor/salary_data_cleaned.csv
# /kaggle/input/jobs-dataset-from-glassdoor/glassdoor_jobs.csv
# /kaggle/input/jobs-dataset-from-glassdoor/eda_data.csv

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv("/kaggle/input/jobs-dataset-from-glassdoor/eda_data.csv")
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded  ... age python_yn R_yn  \
# 0      Goleta, CA   501 to 1000 employees     1973  ...  47         1    0
# 1   Baltimore, MD        10000+ employees     1984  ...  36         1    0
# 2  Clearwater, FL   501 to 1000 employees     2010  ...  10         1    0
# 3    Richland, WA  1001 to 5000 employees     1965  ...  55         1    0
# 4    New York, NY     51 to 200 employees     1998  ...  22         1    0
#
#   spark aws  excel        job_simp  seniority  desc_len  num_comp
# 0     0   0      1  data scientist         na      2536         0
# 1     0   0      0  data scientist         na      4783         0
# 2     1   0      1  data scientist         na      3461         0
# 3     0   0      0  data scientist         na      3883         3
# 4     0   0      1  data scientist         na      2728         3
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Basic Info

# %%
df = df.drop('Unnamed: 0', axis=1)
print(f"Shape: {df.shape}\n")
print(f"{df.columns}\n")
df.info()
# Out:
# Shape: (742, 32)
#
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  hourly             742 non-null    int64
#  15  employer_provided  742 non-null    int64
#  16  min_salary         742 non-null    int64
#  17  max_salary         742 non-null    int64
#  18  avg_salary         742 non-null    float64
#  19  company_txt        742 non-null    object
#  20  job_state          742 non-null    object
#  21  same_state         742 non-null    int64
#  22  age                742 non-null    int64
#  23  python_yn          742 non-null    int64
#  24  R_yn               742 non-null    int64
#  25  spark              742 non-null    int64
#  26  aws                742 non-null    int64
#  27  excel              742 non-null    int64
#  28  job_simp           742 non-null    object
#  29  seniority          742 non-null    object
#  30  desc_len           742 non-null    int64
#  31  num_comp           742 non-null    int64
# dtypes: float64(2), int64(14), object(16)
# memory usage: 185.6+ KB

# %% [markdown]
# ### Basic Statistics

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   46.591644    0.528302    0.002695
# std     45.220324   38.855948    0.496965   53.778815    0.499535    0.051882
# min     16.000000   13.500000    0.000000   -1.000000    0.000000    0.000000
# 25%     96.000000   73.500000    0.000000   11.000000    0.000000    0.000000
# 50%    124.000000   97.500000    1.000000   24.000000    1.000000    0.000000
# 75%    155.000000  122.500000    1.000000   59.000000    1.000000    0.000000
# max    306.000000  254.000000    1.000000  276.000000    1.000000    1.000000
#
#             spark         aws       excel      desc_len    num_comp
# count  742.000000  742.000000  742.000000    742.000000  742.000000
# mean     0.225067    0.237197    0.522911   3869.545822    1.053908
# std      0.417908    0.425651    0.499812   1521.495868    1.384239
# min      0.000000    0.000000    0.000000    407.000000    0.000000
# 25%      0.000000    0.000000    0.000000   2801.000000    0.000000
# 50%      0.000000    0.000000    1.000000   3731.000000    0.000000
# 75%      0.000000    0.000000    1.000000   4740.000000    3.000000
# max      1.000000    1.000000    1.000000  10051.000000    4.000000

# %% [markdown]
# # Cleaning Data

# %%
df.replace("na",np.nan,inplace=True)
df.replace("NaN",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating                 0
# Company Name           0
# Location               0
# Headquarters           0
# Size                   0
# Founded                0
# Type of ownership      0
# Industry               0
# Sector                 0
# Revenue                0
# Competitors            0
# hourly                 0
# employer_provided      0
# min_salary             0
# max_salary             0
# avg_salary             0
# company_txt            0
# job_state              0
# same_state             0
# age                    0
# python_yn              0
# R_yn                   0
# spark                  0
# aws                    0
# excel                  0
# job_simp             184
# seniority            520
# desc_len               0
# num_comp               0
# dtype: int64

# %% [markdown]
# ## Imputation

# %%
print(df['seniority'].unique())
print(df['seniority'].value_counts())
df['seniority'] = df['seniority'].fillna("senior")
# Out:
# [nan 'senior' 'jr']
# seniority
# senior    220
# jr          2
# Name: count, dtype: int64

# %%
df['seniority'].value_counts()
# Out:
# seniority
# senior    740
# jr          2
# Name: count, dtype: int64

# %% [markdown]
# ### Impute using mode

# %%
print(df['job_simp'].unique())
print(df['job_simp'].value_counts())
df['job_simp'] = df['job_simp'].fillna(df['job_simp'].mode()[0])
# Out:
# ['data scientist' nan 'analyst' 'data engineer' 'director' 'manager' 'mle']
# job_simp
# data scientist    279
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: count, dtype: int64

# %%
print(df['job_simp'].value_counts())
# Out:
# job_simp
# data scientist    463
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# job_simp             0
# seniority            0
# desc_len             0
# num_comp             0
# dtype: int64

# %% [markdown]
# ## Removing unknowns

# %%
print(df.min())
# Out:
# Job Title                                            Ag Data Scientist
# Salary Estimate                       $10-$17 Per Hour(Glassdoor est.)
# Job Description      (We are unable to sponsor for this role now or...
# Rating                                                            -1.0
# Company Name                              1-800-FLOWERS.COM, Inc.\n2.8
# Location                                              Agoura Hills, CA
# Headquarters                                                        -1
# Size                                                                -1
# Founded                                                             -1
# Type of ownership                                                   -1
# Industry                                                            -1
# Sector                                                              -1
# Revenue                                         $1 to $2 billion (USD)
# Competitors                                                         -1
# hourly                                                               0
# employer_provided                                                    0
# min_salary                                                          15
# max_salary                                                          16
# avg_salary                                                        13.5
# company_txt                                    1-800-FLOWERS.COM, Inc.
# job_state                                                           AL
# same_state                                                           0
# age                                                                 -1
# python_yn                                                            0
# R_yn                                                                 0
# spark                                                                0
# aws                                                                  0
# excel                                                                0
# job_simp                                                       analyst
# seniority                                                           jr
# desc_len                                                           407
# num_comp                                                             0
# dtype: object

# %% [markdown]
# Min value is -1, which needs to be imputed

# %%
columns_with_min_minus_one = [col for col in df.columns if df[col].min() in (-1,'-1')]

print("Columns where the minimum value is -1:")
print(columns_with_min_minus_one)
# Out:
# Columns where the minimum value is -1:
# ['Rating', 'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Competitors', 'age']

# %%
print(df["Industry"].mode()[0])
df["Industry"][df["Industry"] == "-1"] = df.Industry.mode()[0]
# Out:
# Biotech & Pharmaceuticals
# /tmp/ipykernel_18/2277273944.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Industry"][df["Industry"] == "-1"] = df.Industry.mode()[0]
# /tmp/ipykernel_18/2277273944.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Industry"][df["Industry"] == "-1"] = df.Industry.mode()[0]

# %%
print(df["Type of ownership"].value_counts())
df["Type of ownership"][(df["Type of ownership"] =="-1") | (df["Type of ownership"] =='Unknown')] = "Company - Private"
# Out:
# Type of ownership
# Company - Private                 410
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  3
# School / School District            2
# Unknown                             1
# -1                                  1
# Name: count, dtype: int64
# /tmp/ipykernel_18/3783619838.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Type of ownership"][(df["Type of ownership"] =="-1") | (df["Type of ownership"] =='Unknown')] = "Company - Private"
# /tmp/ipykernel_18/3783619838.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Type of ownership"][(df["Type of ownership"] =="-1") | (df["Type of ownership"] =='Unknown')] = "Company - Private"

# %%
df["Size"].value_counts()
# Out:
# Size
# 1001 to 5000 employees     150
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# Unknown                      9
# -1                           1
# Name: count, dtype: int64

# %%
df["Size"][(df["Size"] == "-1")| (df["Size"] == "Unknown")] = df["Size"].mode()[0]
df["Size"].value_counts()
# Out:
# /tmp/ipykernel_18/3875089315.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Size"][(df["Size"] == "-1")| (df["Size"] == "Unknown")] = df["Size"].mode()[0]
# /tmp/ipykernel_18/3875089315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Size"][(df["Size"] == "-1")| (df["Size"] == "Unknown")] = df["Size"].mode()[0]
# Size
# 1001 to 5000 employees     160
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# Name: count, dtype: int64

# %%
df["Revenue"].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            203
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# -1                                    1
# Name: count, dtype: int64

# %%
df.Revenue[df.Revenue == "-1"] = 'Unknown / Non-Applicable'
print(df['Revenue'].value_counts())
# Out:
# Revenue
# Unknown / Non-Applicable            204
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# Name: count, dtype: int64
# /tmp/ipykernel_18/2543874012.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.Revenue[df.Revenue == "-1"] = 'Unknown / Non-Applicable'
# /tmp/ipykernel_18/2543874012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Revenue[df.Revenue == "-1"] = 'Unknown / Non-Applicable'

# %%
df.replace(-1,np.nan,inplace=True)
df.isnull().sum()
# Out:
# Job Title             0
# Salary Estimate       0
# Job Description       0
# Rating               11
# Company Name          0
# Location              0
# Headquarters          0
# Size                  0
# Founded              50
# Type of ownership     0
# Industry              0
# Sector                0
# Revenue               0
# Competitors           0
# hourly                0
# employer_provided     0
# min_salary            0
# max_salary            0
# avg_salary            0
# company_txt           0
# job_state             0
# same_state            0
# age                  50
# python_yn             0
# R_yn                  0
# spark                 0
# aws                   0
# excel                 0
# job_simp              0
# seniority             0
# desc_len              0
# num_comp              0
# dtype: int64

# %%
#imputation numerical columns
impute = SimpleImputer(strategy="median")
df["Rating"] = impute.fit_transform(df["Rating"].values.reshape(-1,1))
df["Age"] = impute.fit_transform(df["age"].values.reshape(-1,1))
df["Founded"] = impute.fit_transform(df["Founded"].values.reshape(-1,1))

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.688544  1971.454178    0.032345           0.022911   74.719677
# std      0.566106    52.524552    0.177034           0.149721   30.980593
# min      1.900000  1744.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1961.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1992.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  692.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   50.030347    0.528302    0.002695
# std     45.220324   38.855948    0.496965   54.089762    0.499535    0.051882
# min     16.000000   13.500000    0.000000    1.000000    0.000000    0.000000
# 25%     96.000000   73.500000    0.000000   13.000000    0.000000    0.000000
# 50%    124.000000   97.500000    1.000000   28.000000    1.000000    0.000000
# 75%    155.000000  122.500000    1.000000   62.000000    1.000000    0.000000
# max    306.000000  254.000000    1.000000  276.000000    1.000000    1.000000
#
#             spark         aws       excel      desc_len    num_comp  \
# count  742.000000  742.000000  742.000000    742.000000  742.000000
# mean     0.225067    0.237197    0.522911   3869.545822    1.053908
# std      0.417908    0.425651    0.499812   1521.495868    1.384239
# min      0.000000    0.000000    0.000000    407.000000    0.000000
# 25%      0.000000    0.000000    0.000000   2801.000000    0.000000
# 50%      0.000000    0.000000    1.000000   3731.000000    0.000000
# 75%      0.000000    0.000000    1.000000   4740.000000    3.000000
# max      1.000000    1.000000    1.000000  10051.000000    4.000000
#
#               Age
# count  742.000000
# mean    48.545822
# std     52.524552
# min      1.000000
# 25%     13.000000
# 50%     28.000000
# 75%     59.000000
# max    276.000000

# %%
#standard and noraml numerical columns
df_num = df.select_dtypes(include="number")
ss = StandardScaler()

df_num_st = pd.DataFrame(ss.fit_transform(df_num))
df_num_st.columns = ss.get_feature_names_out(df_num.columns)
df_num = df_num_st

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Plot histograms for each column
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# Calculate skewness and kurtosis for each column
skewness = df_num.skew()
kurtosis = df_num.kurtosis()

# Print skewness and kurtosis for each column
for col in df_num.columns:
    print(f"Column: {col}")
    print(f"Skewness: {skewness[col]}")
    print(f"Kurtosis: {kurtosis[col]}")
    print()
# Out:
# Column: Rating
# Skewness: -0.2650567207822845
# Kurtosis: 0.18597079437214115
#
# Column: Founded
# Skewness: -1.8530511869290667
# Kurtosis: 3.0351903582840642
#
# Column: hourly
# Skewness: 5.297499987719976
# Kurtosis: 26.13394099048334
#
# Column: employer_provided
# Skewness: 6.390268857764117
# Kurtosis: 38.94049007088155
#
# Column: min_salary
# Skewness: 1.1092336755520011
# Kurtosis: 1.954967771243124
#
# Column: max_salary
# Skewness: 0.6244715389442066
# Kurtosis: 0.6052151151265996
#
# Column: avg_salary
# Skewness: 0.6094736592509535
# Kurtosis: 0.8891961858304702
#
# Column: same_state
# Skewness: -0.23385178848989452
# Kurtosis: -1.9505782585917066
#
# Column: age
# Skewness: 1.7413091378765273
# Kurtosis: 2.5582425029723526
#
# Column: python_yn
# Skewness: -0.11361915933248869
# Kurtosis: -1.992468516360939
#
# Column: R_yn
# Skewness: 19.222277430318123
# Kurtosis: 368.48917823228595
#
# Column: spark
# Skewness: 1.31931148181632
# Kurtosis: -0.2601256388809161
#
# Column: aws
# Skewness: 1.2381674833553906
# Kurtosis: -0.4682105860031398
#
# Column: excel
# Skewness: -0.09192650740457246
# Kurtosis: -1.9969393979022356
#
# Column: desc_len
# Skewness: 0.7680799739621677
# Kurtosis: 1.0579820288139223
#
# Column: num_comp
# Skewness: 0.6133645811687103
# Kurtosis: -1.5499746402822836
#
# Column: Age
# Skewness: 1.853051186929067
# Kurtosis: 3.035190358284066

# %%
# Assuming your DataFrame is named df

# Create separate box plots for each column
for col in ["Rating","Founded","min_salary","max_salary","avg_salary"]:
    plt.figure(figsize=(6, 4))
    df_num[col].plot(kind='box')
    plt.title(f'Box plot of {col}')
    plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named df

def detect_outliers(df, threshold=1.5):
    outliers = pd.DataFrame()
    for col in ["Rating","Founded","min_salary","max_salary","avg_salary"]:
        if df[col].dtype != 'object':
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - threshold * IQR
            upper_bound = Q3 + threshold * IQR
            col_outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
            outliers = pd.concat([outliers, col_outliers])
    return outliers

# Detect outliers in the DataFrame
outliers_df = detect_outliers(df_num)
outliers_df
# Out:
#        Rating   Founded    hourly  employer_provided  min_salary  max_salary  \
# 77  -3.161513  0.543842 -0.182828          -0.153128   -0.572346   -0.224599
# 304 -2.631219  0.410481 -0.182828          -0.153128    0.299755    0.173721
# 341 -2.807984  0.391430 -0.182828          -0.153128   -0.023246    0.461396
# 380 -3.161513  0.734358 -0.182828          -0.153128   -0.313946   -0.401630
# 417 -2.807984  0.600997 -0.182828          -0.153128   -0.733847   -0.777821
# ..        ...       ...       ...                ...         ...         ...
# 429  1.787895  0.524791 -0.182828          -0.153128    3.271359    3.559437
# 476  0.727308  0.734358 -0.182828          -0.153128    3.723560    2.032545
# 528 -0.686809 -1.132695 -0.182828          -0.153128    4.111160    3.935628
# 613  0.904072  0.753410 -0.182828          -0.153128    3.109859    3.183246
# 708 -0.686809 -1.132695 -0.182828          -0.153128    4.111160    3.935628
#
#      avg_salary  same_state       age  python_yn      R_yn     spark  \
# 77    -0.338040    0.890096 -0.555596  -1.058301 -0.051988 -0.538920
# 304    0.241413   -1.123475 -0.426088  -1.058301 -0.051988 -0.538920
# 341    0.280043    0.890096       NaN  -1.058301 -0.051988 -0.538920
# 380   -0.338040    0.890096 -0.740608   0.944911 -0.051988 -0.538920
# 417   -0.724342    0.890096 -0.611100  -1.058301 -0.051988 -0.538920
# ..          ...         ...       ...        ...       ...       ...
# 429    3.396210   -1.123475 -0.537095   0.944911 -0.051988 -0.538920
# 476    2.687990    0.890096 -0.740608   0.944911 -0.051988  1.855563
# 528    3.949909   -1.123475  1.072506   0.944911 -0.051988 -0.538920
# 613    3.112922    0.890096 -0.759109   0.944911 -0.051988 -0.538920
# 708    3.949909   -1.123475  1.072506   0.944911 -0.051988 -0.538920
#
#           aws     excel  desc_len  num_comp       Age
# 77   1.793296 -1.046922  0.844117 -0.761876 -0.543842
# 304 -0.557633 -1.046922  1.803688  1.406841 -0.410481
# 341 -0.557633  0.955181  0.283106 -0.761876 -0.391430
# 380 -0.557633  0.955181  0.438979  1.406841 -0.734358
# 417 -0.557633  0.955181 -1.651164  0.683935 -0.600997
# ..        ...       ...       ...       ...       ...
# 429 -0.557633 -1.046922 -0.009567 -0.761876 -0.524791
# 476  1.793296 -1.046922  0.110133  1.406841 -0.734358
# 528 -0.557633 -1.046922  0.395571  1.406841  1.132695
# 613 -0.557633  0.955181  0.711263 -0.761876 -0.753410
# 708 -0.557633 -1.046922  0.395571  1.406841  1.132695
#
# [131 rows x 17 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named df

def remove_outliers(df, threshold=1.5):
    clean_df = df.copy()
    for col in ["Rating","Founded","min_salary","max_salary","avg_salary"]:
        if df[col].dtype != 'object':
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - threshold * IQR
            upper_bound = Q3 + threshold * IQR
            clean_df = clean_df[(clean_df[col] >= lower_bound) & (clean_df[col] <= upper_bound)]
    return clean_df

# Remove outliers from the DataFrame
cleaned_df = remove_outliers(df_num)
cleaned_df
# Out:
#        Rating   Founded    hourly  employer_provided  min_salary  max_salary  \
# 0    0.197014  0.029450 -0.182828          -0.153128   -0.701547   -0.822078
# 1   -0.510044  0.239017 -0.182828          -0.153128   -0.378546   -0.357372
# 2    1.964659  0.734358 -0.182828          -0.153128    0.170555   -0.844207
# 3    0.197014 -0.122962 -0.182828          -0.153128   -0.604646   -0.689305
# 4   -1.393867  0.505739 -0.182828          -0.153128    0.364355    0.328623
# ..        ...       ...       ...                ...         ...         ...
# 736 -0.156515  0.867719 -0.182828          -0.153128    0.364355    0.195849
# 738  1.257601  0.658152 -0.182828          -0.153128   -0.087846    0.107334
# 739 -1.924161  0.239017 -0.182828          -0.153128   -0.604646   -0.822078
# 740 -0.863573  0.391430 -0.182828          -0.153128    0.655055    0.704813
# 741 -0.156515 -0.084859 -0.182828          -0.153128   -0.443146   -0.047568
#
#      avg_salary  same_state       age  python_yn      R_yn     spark  \
# 0     -0.737218   -1.123475 -0.056065   0.944911 -0.051988 -0.538920
# 1     -0.338040   -1.123475 -0.259578   0.944911 -0.051988 -0.538920
# 2     -0.402424    0.890096 -0.740608   0.944911 -0.051988  1.855563
# 3     -0.621328    0.890096  0.091944   0.944911 -0.051988 -0.538920
# 4      0.357303    0.890096 -0.518594   0.944911 -0.051988 -0.538920
# ..          ...         ...       ...        ...       ...       ...
# 736    0.280043   -1.123475 -0.870116  -1.058301 -0.051988 -0.538920
# 738    0.048262   -1.123475 -0.666603   0.944911 -0.051988  1.855563
# 739   -0.698588    0.890096 -0.259578  -1.058301 -0.051988 -0.538920
# 740    0.692098   -1.123475       NaN  -1.058301 -0.051988 -0.538920
# 741   -0.183519   -1.123475  0.054942   0.944911 -0.051988 -0.538920
#
#           aws     excel  desc_len  num_comp       Age
# 0   -0.557633  0.955181 -0.877061 -0.761876 -0.029450
# 1   -0.557633 -1.046922  0.600771 -0.761876 -0.239017
# 2   -0.557633  0.955181 -0.268697 -0.761876 -0.734358
# 3   -0.557633 -1.046922  0.008849  1.406841  0.122962
# 4   -0.557633  0.955181 -0.750785  1.406841 -0.505739
# ..        ...       ...       ...       ...       ...
# 736 -0.557633 -1.046922  0.759932  1.406841 -0.867719
# 738  1.793296 -1.046922  1.486681  1.406841 -0.658152
# 739 -0.557633  0.955181 -0.520593 -0.761876 -0.239017
# 740 -0.557633  0.955181 -1.465037 -0.761876 -0.391430
# 741 -0.557633 -1.046922 -0.129266 -0.761876  0.084859
#
# [630 rows x 17 columns]

# %% [markdown]
# ## Visualisations

# %%
#Type of jobs in data
job_title_counts = df['Job Title'].value_counts()

# Plot the top 10 job titles
plt.figure(figsize=(10, 6))
sns.barplot(x=job_title_counts.head(10), y=job_title_counts.head(10).index, orient='h')
plt.title('Top 10 Job Titles')
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.show()

# %%
#Top 10 city pay the highest salary
plt.figure(figsize = (15,9))
city = pd.pivot_table(df, index = 'Location', values = 'avg_salary', aggfunc = np.mean).reset_index()
city = city.sort_values('avg_salary', ascending = False)
city_10 = city.head(10)
plt.title('Top 10 region have the highest average salary', size = 30, color = 'red')
sns.barplot(city_10, x = 'Location', y = 'avg_salary')
# Out:
# /tmp/ipykernel_18/630929902.py:3: FutureWarning: The provided callable <function mean at 0x7b05341b84c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   city = pd.pivot_table(df, index = 'Location', values = 'avg_salary', aggfunc = np.mean).reset_index()
# <Axes: title={'center': 'Top 10 region have the highest average salary'}, xlabel='Location', ylabel='avg_salary'>

# %%
# Create a histogram of company ratings
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], bins=20, kde=True)
plt.title('Company Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import plotly.express as px

# Assuming you have the 'Industry' column in data2
industry_counts = df['Industry'].value_counts().head(10)

# Create a DataFrame for the top 10 industries and their counts, sorted in descending order
top_industries_df = pd.DataFrame({'Industry': industry_counts.index, 'Count': industry_counts.values})
top_industries_df = top_industries_df.sort_values(by='Count', ascending=True)

# Create an interactive bar plot using Plotly Express
fig = px.bar(top_industries_df, x='Count', y='Industry', orientation='h',
             title='Top 10 Industries by Job Listings (Descending Order)')
fig.update_xaxes(title='Count')
fig.update_yaxes(title='Industry')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="16f52b1c-65f5-413e-9a17-e066a4f654df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16f52b1c-65f5-413e-9a17-e066a4f654df")) {                    Plotly.newPlot(                        "16f52b1c-65f5-413e-9a17-e066a4f654df",                        [{"alignmentgroup":"True","hovertemplate":"Count=%{x}\u003cbr\u003eIndustry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[25,25,29,29,42,49,50,59,63,122],"xaxis":"x","y":["Aerospace & Defense","Advertising & Marketing","Internet","Consulting","Enterprise Software & Network Solutions","Health Care Services & Hospitals","IT Services","Computer Hardware & Software","Insurance Carriers","Biotech & Pharmaceuticals"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"l ...

# %%
#Ranking kind of Company
df_job = df
type_com = []
for i in df_job['Founded']:
    if i==-1:
        type_com.append('No info')
    elif i<=1980:
        type_com.append('Old Company')
    elif 1980<i<2000:
        type_com.append('Mid Age Company')
    elif 2000<=i<2020:
        type_com.append('Young Company')
    else:
        type_com.append('New Company')
df_job['Kind of Company'] = type_com

plt.figure(figsize =(8,6))
plt.title('Kind of companies', size = 30, color = 'blue')
sns.histplot(df_job['Kind of Company'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: title={'center': 'Kind of companies'}, xlabel='Kind of Company', ylabel='Count'>

# %%
#Ranking scale of company
size_com = []
for i in df_job['Size']:
    if i ==-1 or i =='Unknow':
        size_com.append('No Info')
    elif i=='1 to 50 employees'or i=='51 to 200 employees':
        size_com.append('Small')
    elif i =='201 to 500 employees' or i =='501 to 1000 employees':
        size_com.append('Medium')
    elif i=='1001 to 5000 employees' or i =='5001 to 10000 employees':
        size_com.append('Big')
    else:
        size_com.append('Enormous')
df_job['Size_com'] = size_com

plt.figure(figsize =(8,6))
plt.title('Size of companies', size = 30, color ='blue')
sns.histplot(df_job['Size_com'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: title={'center': 'Size of companies'}, xlabel='Size_com', ylabel='Count'>

# %%
#What type of company ready for a high salary?
high_com_salary = pd.pivot_table(df_job,index = 'Size_com', values = 'avg_salary', aggfunc = np.mean).reset_index()
plt.title('Average slary by size of companies', size = 15, color = 'red')
sns.barplot(high_com_salary,x = 'Size_com', y='avg_salary')
# Out:
# /tmp/ipykernel_18/988251807.py:2: FutureWarning:
#
# The provided callable <function mean at 0x7b05341b84c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
# <Axes: title={'center': 'Average slary by size of companies'}, xlabel='Size_com', ylabel='avg_salary'>

# %%
salary = pd.read_csv('/kaggle/input/jobs-dataset-from-glassdoor/salary_data_cleaned.csv')
high_salary_100 = salary['avg_salary'].sort_values(ascending=False).head(100)
high_salary_100
# avg_salary to 100th in high ranking 254.0 ~ 142.5
high_salary_100_data = salary.loc[high_salary_100.index]
high_salary_100_data['salary_grade'] = 'high'

low_salary_100 = salary['avg_salary'].sort_values().head(100)
low_salary_100
# avg_salary to 100th in low ranking 13.5 ~ 61.0
# select and labeling for low_salary data 

low_salary_100_data = salary.loc[low_salary_100.index]
low_salary_100_data['salary_grade'] = 'low'

# %%
import plotly.express as ex
ex.pie(high_salary_100_data, names='Job Title',title='high salary Job',hole=0.3, width=1000, height=800)
# Out:
# <div>                            <div id="3e2fb071-3565-4e30-be34-d4746a9d31da" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e2fb071-3565-4e30-be34-d4746a9d31da")) {                    Plotly.newPlot(                        "3e2fb071-3565-4e30-be34-d4746a9d31da",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Job Title=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Director II, Data Science - GRM Actuarial","Director II, Data Science - GRM Actuarial","Director II, Data Science - GRM Actuarial","Senior Data Scientist","Principal Machine Learning Scientist","Principal Data Scientist with over 10 years experience","Principal Data Scientist with over 10 years experience","Data Science Manager","Lead Data Engineer","Lead Data Engineer","Lead Data Engineer","Director II, Data Science - GRS Predictive Analytics","Director II, Data Science - GRS Predictive Analytics","Principal Data Scientist","Principal Data Scientist","Lead Data Scientist","Lead Data Scientist","Staff Machine Learning Engineer","Staff Machine Learning Engineer","Staff Machine Learning Engineer","Lead Data Scientist","Lead Data Scientist","Director, Data Science","Staff Data Engineer","Sr. Scientist II","Senior Quantitative Analyst","Principal Data Scientist","Principal Data Scientist","Director, Precision Medicine Clinical Biomarker Scientist","Data Scientist - Alpha Insights","Staff Data Scientist","Staff Data Scientist","Senior Data Scientist","Sr. Data Scientist - Analytics, Personalized Healthcare (PHC)","Sr. Data Scientist - Analytics, Personalized Healthcare (PHC)","Scientist 2, QC Viral Vector","Data Scientist - Sales","Research Scientist \u002f Principal Research Scientist - Multiphysical Systems","Senior Manager, Epidemiologic Data Scientist","Senior Manager, Epidemiologic Data Scientist","Senior Data Scientist - Algorithms","Data Scientist","Data Scientist","Lead Data Scientist","Lead Data Scientist","Data Scientist","Data Scientist","Principal Data Engineer, Data Platform & Insights","Lead Big Data Engineer","Data Science Engineer - Mobile","Lead Big Data Engineer","Data Science Engineer - Mobile","Sr. Scientist, Quantitative Translational Sciences","Director Data Science","Sr. Scientist, Quantitative Translational Sciences","Director Data Science","Data Scientist","Sr. Data Scientist, Cyber-Security LT Contract","Data Scientist","Data Scientist","Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence","Senior Scientist (Neuroscience)","Data Scientist","Senior Scientist (Neuroscience)","Senior Scientist (Neuroscience)","Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence","Data Scientist","Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence","Customer Data Scientist","Customer Data Scientist","Senior Data Scientist","Data Scientist","Senior Data Scientist","Sr. Scientist - Digital & Image Analysis\u002fComputational Pathology","Sr. Scientist - Digital & Image Analysis\u002fComputational Pathology","Customer Data Scientist\u002fSales Engineer (Bay","Senior Data Scientist","Senior Data Scientist","Staff Data Engineer","Staff Data Engineer","Senior Data Scientist","Senior Data Scientist","Principal Data Scientist","Senior Data Scientist","Senior Data Scientist","Data Scientist Manager","Sr. Data Scientist II","Sr. Data Scientist II","PL Actuarial-Lead Data Scientist","PL Actuarial-Lead Data Scientist","Data Engineer I","Data Scientist","Senior Scientist - Neuroscience","Senior Scientist - Neuroscience","Data Scientist","Data Scientist","Data Scientist","Data Scientist","Data Scientist","Data Scientist - Algorithms & Inference"],"legendgroup":"","name":"","showleg ...

# %%
ex.pie(low_salary_100_data, names='Job Title',title='low salary Job',hole=0.3, width=1000, height=800)
# Out:
# <div>                            <div id="6b0a9908-252a-498a-a343-341ff2ff6ddb" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b0a9908-252a-498a-a343-341ff2ff6ddb")) {                    Plotly.newPlot(                        "6b0a9908-252a-498a-a343-341ff2ff6ddb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Job Title=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Senior Operations Data Analyst, Call Center Operations","Senior Operations Data Analyst, Call Center Operations","Data Scientist","Medical Technologist \u002f Clinical Laboratory Scientist","Medical Lab Scientist","Medical Lab Scientist","Medical Laboratory Scientist","Medical Laboratory Scientist","Medical Laboratory Scientist","Medical Laboratory Scientist","Medical Lab Scientist - MLT","Medical Lab Scientist - MLT","ENVIRONMENTAL ENGINEER\u002fSCIENTIST","ENVIRONMENTAL ENGINEER\u002fSCIENTIST","ENVIRONMENTAL ENGINEER\u002fSCIENTIST","MED TECH\u002fLAB SCIENTIST- SOUTH COASTAL LAB","MED TECH\u002fLAB SCIENTIST- SOUTH COASTAL LAB","MED TECH\u002fLAB SCIENTIST- SOUTH COASTAL LAB","MED TECH\u002fLAB SCIENTIST - LABORATORY","MED TECH\u002fLAB SCIENTIST - LABORATORY","MED TECH\u002fLAB SCIENTIST- SOUTH COASTAL LAB","Associate Data Analyst","Clinical Laboratory Scientist","Clinical Laboratory Scientist","Clinical Laboratory Scientist","Clinical Scientist, Clinical Development","Clinical Data Analyst","Clinical Data Analyst","Project Scientist","Data Analytics Manager","Analytics - Business Assurance Data Analyst","Analytics - Business Assurance Data Analyst","Market Data Analyst","Market Data Analyst","Foundational Community Supports Data Analyst","Associate Data Analyst- Graduate Development Program","Associate Data Analyst- Graduate Development Program","Associate Data Analyst- Graduate Development Program","Lead Data Analyst","Lead Data Analyst","Supply Chain Data Analyst","Data Analyst","Associate Data Analyst","Data Management Specialist","E-Commerce Data Analyst","Marketing Data Analyst","Marketing Data Analyst","Marketing Data Analyst","Marketing Data Analyst","Data Analyst","Marketing Data Analyst","Marketing Data Analyst","Data Analyst 1, full-time contract worker for up to 12 months","Data Analyst 1, full-time contract worker for up to 12 months","Junior Data Analyst","Associate Environmental Scientist - Wildlife Biologist","Associate Environmental Scientist - Wildlife Biologist","Digital Marketing & ECommerce Data Analyst","Digital Marketing & ECommerce Data Analyst","Data Modeler - Data Solutions Engineer","Data Modeler - Data Solutions Engineer","R&D Specialist\u002f Food Scientist","Research Scientist","R&D Specialist\u002f Food Scientist","R&D Specialist\u002f Food Scientist","CONSULTANT– DATA ANALYTICS GROUP","R&D Specialist\u002f Food Scientist","Assistant Director\u002fDirector, Office of Data Science","Business Data Analyst","Business Data Analyst","Data Analyst","Food Scientist - Developer","IT Associate Data Analyst","Food Scientist - Developer","Food Scientist - Developer","IT Associate Data Analyst","Food Scientist - Developer","Senior Data Analyst","Data Analyst","Financial Data Analyst","Jr. Business Data Analyst","Data Scientist - Research","Information Security Data Analyst","Data Engineering Analyst","Radar Data Analyst","Radar Data Analyst","System and Data Analyst","Data Analyst","Corporate Risk Data Analyst (SQL Based) - Milwaukee or","RESEARCH SCIENTIST - BIOLOGICAL SAFETY","Corporate Risk Data Analyst (SQL Based) - Milwaukee or","Data Engineer","Staff Scientist","Senior Data Analyst","Excel \u002f VBA \u002f SQL Data Analyst","Information Security Data Analyst","Senior Data Analyst","Information Security Data Analyst","Research Scientist", ...

# %%
# Compute the correlation matrix
correlation_matrix = df_num.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
correlation_matrix['avg_salary']
# Out:
# Rating               0.131874
# Founded             -0.021892
# hourly              -0.356082
# employer_provided    0.076287
# min_salary           0.967765
# max_salary           0.986862
# avg_salary           1.000000
# same_state          -0.034641
# age                  0.023808
# python_yn            0.327796
# R_yn                -0.040000
# spark                0.176559
# aws                  0.171379
# excel               -0.057252
# desc_len             0.078808
# num_comp             0.093813
# Age                  0.021892
# Name: avg_salary, dtype: float64

# %%
correlation_threshold = 0.3

# %%
# Get columns with correlation higher than 0.15 with respect to the column 'actual'
high_corr_columns = correlation_matrix[abs(correlation_matrix['avg_salary']) > correlation_threshold]['avg_salary'].index.tolist()

# Remove 'actual' itself from the list if it's included
high_corr_columns.remove('avg_salary')

print("Columns with correlation higher than threshold with respect to 'actual':")
print(high_corr_columns)
# Out:
# Columns with correlation higher than threshold with respect to 'actual':
# ['hourly', 'min_salary', 'max_salary', 'python_yn']

# %%
from sklearn.model_selection import train_test_split
X = df_num[['hourly', 'min_salary', 'max_salary', 'python_yn']]
Y=df_num['avg_salary']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.15,random_state=100)
print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
# Out:
# (630, 4)
# (112, 4)
# (630,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-1.11416446e-01  3.99976227e-01  5.79042532e-01  3.40999824e-04]
# 0.0005758879374543127

# %%
AcPr_data = pd.DataFrame({'Actual': y_test, 'predicted': prediction,'range':[i for i in range(len(y_test.index))]})
AcPr_data
# Out:
#        Actual  predicted  range
# 659 -0.350917  -0.349994      0
# 569 -0.093382  -0.093195      1
# 153  0.228536   0.229047      2
# 19  -0.338040  -0.336969      3
# 405 -0.878862  -0.877513      4
# ..        ...        ...    ...
# 203 -1.200780  -1.198697    107
# 564 -1.046260  -1.044618    108
# 54   0.228536   0.227835    109
# 366 -1.007630  -1.005965    110
# 594  0.511824   0.510156    111
#
# [112 rows x 3 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.scatter(x=AcPr_data['range'], y=AcPr_data['Actual'], s=10, c='b', marker="s", label='Actual',)
ax.scatter(x=AcPr_data['range'],y=AcPr_data['predicted'], s=10, c='r', marker="o", label='Predicted')
plt.legend(loc='upper left')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, prediction)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.0005240875425632242

# %%
def accuracy_within_tolerance(test, pred, tolerance):
    """
    Calculates the percentage of predictions within a specified tolerance of the true values.
    
    Parameters:
        test (array-like): Array of true target values.
        pred (array-like): Array of predicted values.
        tolerance (float): Tolerance value.
        
    Returns:
        accuracy (float): Percentage of predictions within the tolerance.
    """
    # Calculate absolute errors
    errors = abs(test - pred)
    
    # Count number of predictions within tolerance
    within_tolerance = sum(errors <= tolerance)
    
    # Calculate accuracy
    accuracy = within_tolerance / len(test)
    
    return accuracy*100

# %%
accuracy_within_tolerance(y_test, prediction, 0.05)
# Out:
# 94.64285714285714

# %%
np.random.seed(0)
test_values = np.random.rand(100)
pred_values = test_values + np.random.normal(0, 0.1, 100)  # Adding noise to create predicted values
tolerance_values = np.linspace(0, 0.5, 50)  # Tolerance values from 0 to 0.5

# Calculate accuracy for each tolerance level
accuracy_values = [accuracy_within_tolerance(test_values, pred_values, tol) for tol in tolerance_values]

# Plot accuracy vs tolerance
plt.figure(figsize=(8, 6))
plt.plot(tolerance_values, accuracy_values, marker='o', linestyle='-')
plt.title('Accuracy vs Tolerance')
plt.xlabel('Tolerance')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
